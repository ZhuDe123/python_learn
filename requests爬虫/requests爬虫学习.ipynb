# %% [markdown]
# # 发送请求

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
r = requests.put('http://httpbin.org/put', data = {'key':'value'})
r = requests.delete('http://httpbin.org/delete')
r = requests.head('http://httpbin.org/get')
r = requests.options('http://httpbin.org/get')

# %% [markdown]
# # 传递 URL 参数
#
# Requests 允许你使用 params 关键字参数，以一个字符串字典来提供这些参数。

# %%
#注意字典里值为 None 的键都不会被添加到 URL 的查询字符串里。
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
print(r.url)
# Out:
# http://httpbin.org/get?key1=value1&key2=value2

# %% [markdown]
# # 响应内容
#
# Requests 会自动解码来自服务器的内容。大多数 unicode 字符集都能被无缝地解码。
#
# 请求发出后，Requests 会基于 HTTP 头部对响应的编码作出有根据的推测。当你访问 r.text 之时，Requests 会使用其推测的文本编码。你可以找出 Requests 使用了什么编码，并且能够使用 r.encoding 属性来改变它：

# %%
r = requests.get("http://httpbin.org/get")
print(r.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-61cafed2-54df971329e7deea70e24af5"
#   },
#   "origin": "39.144.177.16",
#   "url": "http://httpbin.org/get"
# }

# %%
print(r.encoding)
r.encoding = 'ISO-8859-1'
print(r.encoding)

print(r.text)
# Out:
# ISO-8859-1
# ISO-8859-1
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-61cafed2-54df971329e7deea70e24af5"
#   },
#   "origin": "39.144.177.16",
#   "url": "http://httpbin.org/get"
# }

# %% [markdown]
# 你可能希望在使用特殊逻辑计算出文本的编码的情况下来修改编码。比如 HTTP 和 XML 自身可以指定编码。这样的话，你应该使用 r.content 来找到编码，然后设置 r.encoding 为相应的编码。这样就能使用正确的编码解析 r.text 了。
#
# # 二进制响应内容
#
# 你也能以字节的方式访问请求响应体，对于非文本请求
#
# Requests 会自动为你解码 gzip 和 deflate 传输编码的响应数据。
#
# 例如，以请求返回的二进制数据创建一张图片，你可以使用如下代码：

# %%
import requests
from PIL import Image
from io import BytesIO
#图片地址https://t7.baidu.com/it/u=1819248061,230866778&fm=193&f=GIF
r = requests.get("https://t7.baidu.com/it/u=1819248061,230866778&fm=193&f=GIF")
i = Image.open(BytesIO(r.content))
#展示图片
i.show()
#保存图片
i.save("a.png")

# 第二种方法
with open("b.png","wb") as f1:
    f1.write(r.content)

# %% [markdown]
# # JSON 响应内容
#
# Requests 中也有一个内置的 JSON 解码器，助你处理 JSON 数据：

# %%
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '19506116362',
#   'type': 'PushEvent',
#   'actor': {'id': 61287791,
#    'login': 'Sumonta056',
#    'display_login': 'Sumonta056',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sumonta056',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61287791?'},
#   'repo': {'id': 342791138,
#    'name': 'Sumonta056/sumonta056',
#    'url': 'https://api.github.com/repos/Sumonta056/sumonta056'},
#   'payload': {'push_id': 8712208888,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ef9c9fef61d979a40645dcdb020383966f6059ad',
#    'before': '16db0b1485fc858726b6af492f945889696f9040',
#    'commits': [{'sha': 'ef9c9fef61d979a40645dcdb020383966f6059ad',
#      'author': {'email': 'sumontasaha80@gmail.com',
#       'name': 'Sumonta Saha Mridul'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sumonta056/sumonta056/commits/ef9c9fef61d979a40645dcdb020383966f6059ad'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116345',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 438337590,
#    'name': 'patriciogsilva/patriciogsilva',
#    'url': 'https://api.github.com/repos/patriciogsilva/patriciogsilva'},
#   'payload': {'push_id': 8712208886,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '1a16ec234e59e31ca7b53cb45ba002772c711371',
#    'before': 'd38524efd15b67dbdbc844d046bc9551a83fd309',
#    'commits': [{'sha': '1a16ec234e59e31ca7b53cb45ba002772c711371',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/patriciogsilva/patriciogsilva/commits/1a16ec234e59e31ca7b53cb45ba002772c711371'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116333',
#   'type': 'PushEvent',
#   'actor': {'id': 10375845,
#    'login': 'TobiasReich',
#    'display_login': 'TobiasReich',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TobiasReich',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10375845?'},
#   'repo': {'id': 437523336,
#    'name': 'TobiasReich/Kaiser3',
#    'url': 'https://api.github.com/repos/TobiasReich/Kaiser3'},
#   'payload': {'push_id': 8712208885,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a2214c45cac48b993be15c0ae8fc7179bc86cced',
#    'before': 'd0a414047b9c40dcca400831d36ae5b6b6b217a1',
#    'commits': [{'sha': 'a2214c45cac48b993be15c0ae8fc7179bc86cced',
#      'author': {'email': 'mad.scientist@freenet.de', 'name': 'TobiasReich'},
#      'message': 'Players now having a map of military units',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TobiasReich/Kaiser3/commits/a2214c45cac48b993be15c0ae8fc7179bc86cced'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116363',
#   'type': 'PushEvent',
#   'actor': {'id': 95190966,
#    'login': 'MarineStl',
#    'display_login': 'MarineStl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarineStl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95190966?'},
#   'repo': {'id': 442463528,
#    'name': 'MarineStl/QUIZZ',
#    'url': 'https://api.github.com/repos/MarineStl/QUIZZ'},
#   'payload': {'push_id': 8712208902,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2804b47fe99fa457d5bf990bf712ec92b9a90c0d',
#    'before': '398ca373dd5119094fcf3dda006c9c391e5293b8',
#    'commits': [{'sha': '2804b47fe99fa457d5bf990bf712ec92b9a90c0d',
#      'author': {'email': '95190966+MarineStl@users.noreply.github.com',
#       'name': 'MarineStl'},
#      'message': 'Delete wireframe',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MarineStl/QUIZZ/commits/2804b47fe99fa457d5bf990bf712ec92b9a90c0d'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116339',
#   'type': 'PushEvent',
#   'actor': {'id': 21364403,
#    'login': 'lemuringen',
#    'display_login': 'lemuringen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lemuringen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21364403?'},
#   'repo': {'id': 435501947,
#    'name': 'AdamBrodin/th2103-g07',
#    'url': 'https://api.github.com/repos/AdamBrodin/th2103-g07'},
#   'payload': {'push_id': 8712208874,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/my-bookings-page',
#    'head': 'c458825504c698fe657df3069cab75a7774eeb65',
#    'before': '7a0ae0bbf6bfcd1e2ae2af6c723d67f0912c52c5',
#    'commits': [{'sha': 'c458825504c698fe657df3069cab75a7774eeb65',
#      'author': {'email': 'Jesper.Utriainen@protonmail.com',
#       'name': 'lemuringen'},
#      'message': 'GUI for searching and deleting bookings. Purely visual as is.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AdamBrodin/th2103-g07/commits/c458825504c698fe657df3069cab75a7774eeb65'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116346',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 5655515,
#    'login': 'emylincon',
#    'display_login': 'emylincon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/emylincon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?'},
#   'repo': {'id': 442260120,
#    'name': 'emylincon/golist',
#    'url': 'https://api.github.com/repos/emylincon/golist'},
#   'payload': {'action': 'closed',
#    'number': 10,
#    'pull_request': {'url': 'https://api.github.com/repos/emylincon/golist/pulls/10',
#     'id': 810939896,
#     'node_id': 'PR_kwDOGlxamM4wVfX4',
#     'html_url': 'https://github.com/emylincon/golist/pull/10',
#     'diff_url': 'https://github.com/emylincon/golist/pull/10.diff',
#     'patch_url': 'https://github.com/emylincon/golist/pull/10.patch',
#     'issue_url': 'https://api.github.com/repos/emylincon/golist/issues/10',
#     'number': 10,
#     'state': 'closed',
#     'locked': False,
#     'title': '#9 added reverse sort functionality',
#     'user': {'login': 'emylincon',
#      'id': 5655515,
#      'node_id': 'MDQ6VXNlcjU2NTU1MTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/emylincon',
#      'html_url': 'https://github.com/emylincon',
#      'followers_url': 'https://api.github.com/users/emylincon/followers',
#      'following_url': 'https://api.github.com/users/emylincon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/emylincon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/emylincon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/emylincon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/emylincon/orgs',
#      'repos_url': 'https://api.github.com/users/emylincon/repos',
#      'events_url': 'https://api.github.com/users/emylincon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/emylincon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'reverse sort function: resolves #9 ',
#     'created_at': '2021-12-28T13:02:33Z',
#     'updated_at': '2021-12-28T13:03:22Z',
#     'closed_at': '2021-12-28T13:03:22Z',
#     'merged_at': '2021-12-28T13:03:22Z',
#     'merge_commit_sha': '7ec9ad15558f3b4c482730fcb14e9d4f23a7099a',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/emylincon/golist/pulls/10/commits',
#     'review_comments_url': 'https://api.github.com/repos/emylincon/golist/pulls/10/comments',
#     'review_comment_url': 'https://api.github.com/repos/emylincon/golist/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/emylincon/golist/issues/10/comments',
#     'statuses_url': 'https://api.github.com/repos/emylincon/golist/statuses/a8f81aad1da4506ecf458b233529afec3a2ce6d1',
#     'head': {'label': 'emylincon:9-add-reverse-sort',
#      'ref': '9-add-reverse-sort',
#      'sha': 'a8f81aad1da4506ecf458b233529afec3a2ce6d1',
#      'user': {'login': 'emylincon',
#       'id': 5655515,
#       'node_id': 'MDQ6VXNlcjU2NTU1MTU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/emylincon',
#       'html_url': 'https://github.com/emylincon',
#       'followers_url': 'https://api.github.com/users/emylincon/followers',
#       'following_url': 'https://api.github.com/users/emylincon/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/emylincon/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/emylincon/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/emylincon/subscriptions',
#       'organizations_url': 'https://api.github.com/users/emylincon/orgs',
#       'repos_url': 'https://api.github.com/users/emylincon/repos',
#       'events_url': 'https://api.github.com/users/emylincon/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/emylincon/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 442260120,
#       'node_id': 'R_kgDOGlxamA',
#       'name': 'golist',
#       'full_name': 'emylincon/golist',
#       'private': False,
#       'owner': {'login': 'emylincon',
#        'id': 5655515,
#        'node_id': 'MDQ6VXNlcjU2NTU1MTU=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/emylincon',
#        'html_url': 'https://github.com/emylincon',
#        'followers_url': 'https://api.github.com/users/emylincon/followers',
#        'following_url': 'https://api.github.com/users/emylincon/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/emylincon/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/emylincon/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/emylincon/subscriptions',
#        'organizations_url': 'https://api.github.com/users/emylincon/orgs',
#        'repos_url': 'https://api.github.com/users/emylincon/repos',
#        'events_url': 'https://api.github.com/users/emylincon/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/emylincon/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/emylincon/golist',
#       'description': 'A customized go list with index, sort, append, pop, count, clear and last item methods',
#       'fork': False,
#       'url': 'https://api.github.com/repos/emylincon/golist',
#       'forks_url': 'https://api.github.com/repos/emylincon/golist/forks',
#       'keys_url': 'https://api.github.com/repos/emylincon/golist/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/emylincon/golist/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/emylincon/golist/teams',
#       'hooks_url': 'https://api.github.com/repos/emylincon/golist/hooks',
#       'issue_events_url': 'https://api.github.com/repos/emylincon/golist/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/emylincon/golist/events',
#       'assignees_url': 'https://api.github.com/repos/emylincon/golist/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/emylincon/golist/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/emylincon/golist/tags',
#       'blobs_url': 'https://api.github.com/repos/emylincon/golist/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/emylincon/golist/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/emylincon/golist/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/emylincon/golist/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/emylincon/golist/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/emylincon/golist/languages',
#       'stargazers_url': 'https://api.github.com/repos/emylincon/golist/stargazers',
#       'contributors_url': 'https://api.github.com/repos/emylincon/golist/contributors',
#       'subscribers_url': 'https://api.github.com/repos/emylincon/golist/subscribers',
#       'subscription_url': 'https://api.github.com/repos/emylincon/golist/subscription',
#       'commits_url': 'https://api.github.com/repos/emylincon/golist/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/emylincon/golist/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/emylincon/golist/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/emylincon/golist/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/emylincon/golist/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/emylincon/golist/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/emylincon/golist/merges',
#       'archive_url': 'https://api.github.com/repos/emylincon/golist/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/emylincon/golist/downloads',
#       'issues_url': 'https://api.github.com/repos/emylincon/golist/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/emylincon/golist/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/emylincon/golist/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/emylincon/golist/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/emylincon/golist/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/emylincon/golist/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/emylincon/golist/deployments',
#       'created_at': '2021-12-27T19:57:09Z',
#       'updated_at': '2021-12-28T11:23:36Z',
#       'pushed_at': '2021-12-28T13:03:22Z',
#       'git_url': 'git://github.com/emylincon/golist.git',
#       'ssh_url': 'git@github.com:emylincon/golist.git',
#       'clone_url': 'https://github.com/emylincon/golist.git',
#       'svn_url': 'https://github.com/emylincon/golist',
#       'homepage': None,
#       'size': 13,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'emylincon:main',
#      'ref': 'main',
#      'sha': '8e0a3fde1a764523c6ce0d436292ffacb41bea40',
#      'user': {'login': 'emylincon',
#       'id': 5655515,
#       'node_id': 'MDQ6VXNlcjU2NTU1MTU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/emylincon',
#       'html_url': 'https://github.com/emylincon',
#       'followers_url': 'https://api.github.com/users/emylincon/followers',
#       'following_url': 'https://api.github.com/users/emylincon/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/emylincon/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/emylincon/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/emylincon/subscriptions',
#       'organizations_url': 'https://api.github.com/users/emylincon/orgs',
#       'repos_url': 'https://api.github.com/users/emylincon/repos',
#       'events_url': 'https://api.github.com/users/emylincon/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/emylincon/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 442260120,
#       'node_id': 'R_kgDOGlxamA',
#       'name': 'golist',
#       'full_name': 'emylincon/golist',
#       'private': False,
#       'owner': {'login': 'emylincon',
#        'id': 5655515,
#        'node_id': 'MDQ6VXNlcjU2NTU1MTU=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/emylincon',
#        'html_url': 'https://github.com/emylincon',
#        'followers_url': 'https://api.github.com/users/emylincon/followers',
#        'following_url': 'https://api.github.com/users/emylincon/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/emylincon/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/emylincon/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/emylincon/subscriptions',
#        'organizations_url': 'https://api.github.com/users/emylincon/orgs',
#        'repos_url': 'https://api.github.com/users/emylincon/repos',
#        'events_url': 'https://api.github.com/users/emylincon/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/emylincon/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/emylincon/golist',
#       'description': 'A customized go list with index, sort, append, pop, count, clear and last item methods',
#       'fork': False,
#       'url': 'https://api.github.com/repos/emylincon/golist',
#       'forks_url': 'https://api.github.com/repos/emylincon/golist/forks',
#       'keys_url': 'https://api.github.com/repos/emylincon/golist/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/emylincon/golist/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/emylincon/golist/teams',
#       'hooks_url': 'https://api.github.com/repos/emylincon/golist/hooks',
#       'issue_events_url': 'https://api.github.com/repos/emylincon/golist/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/emylincon/golist/events',
#       'assignees_url': 'https://api.github.com/repos/emylincon/golist/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/emylincon/golist/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/emylincon/golist/tags',
#       'blobs_url': 'https://api.github.com/repos/emylincon/golist/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/emylincon/golist/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/emylincon/golist/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/emylincon/golist/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/emylincon/golist/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/emylincon/golist/languages',
#       'stargazers_url': 'https://api.github.com/repos/emylincon/golist/stargazers',
#       'contributors_url': 'https://api.github.com/repos/emylincon/golist/contributors',
#       'subscribers_url': 'https://api.github.com/repos/emylincon/golist/subscribers',
#       'subscription_url': 'https://api.github.com/repos/emylincon/golist/subscription',
#       'commits_url': 'https://api.github.com/repos/emylincon/golist/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/emylincon/golist/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/emylincon/golist/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/emylincon/golist/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/emylincon/golist/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/emylincon/golist/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/emylincon/golist/merges',
#       'archive_url': 'https://api.github.com/repos/emylincon/golist/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/emylincon/golist/downloads',
#       'issues_url': 'https://api.github.com/repos/emylincon/golist/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/emylincon/golist/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/emylincon/golist/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/emylincon/golist/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/emylincon/golist/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/emylincon/golist/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/emylincon/golist/deployments',
#       'created_at': '2021-12-27T19:57:09Z',
#       'updated_at': '2021-12-28T11:23:36Z',
#       'pushed_at': '2021-12-28T13:03:22Z',
#       'git_url': 'git://github.com/emylincon/golist.git',
#       'ssh_url': 'git@github.com:emylincon/golist.git',
#       'clone_url': 'https://github.com/emylincon/golist.git',
#       'svn_url': 'https://github.com/emylincon/golist',
#       'homepage': None,
#       'size': 13,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/emylincon/golist/pulls/10'},
#      'html': {'href': 'https://github.com/emylincon/golist/pull/10'},
#      'issue': {'href': 'https://api.github.com/repos/emylincon/golist/issues/10'},
#      'comments': {'href': 'https://api.github.com/repos/emylincon/golist/issues/10/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/emylincon/golist/pulls/10/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/emylincon/golist/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/emylincon/golist/pulls/10/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/emylincon/golist/statuses/a8f81aad1da4506ecf458b233529afec3a2ce6d1'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'emylincon',
#      'id': 5655515,
#      'node_id': 'MDQ6VXNlcjU2NTU1MTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/emylincon',
#      'html_url': 'https://github.com/emylincon',
#      'followers_url': 'https://api.github.com/users/emylincon/followers',
#      'following_url': 'https://api.github.com/users/emylincon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/emylincon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/emylincon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/emylincon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/emylincon/orgs',
#      'repos_url': 'https://api.github.com/users/emylincon/repos',
#      'events_url': 'https://api.github.com/users/emylincon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/emylincon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 142,
#     'deletions': 44,
#     'changed_files': 8}},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116335',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 394348003,
#    'name': 'AlongWY/ArxivDaily',
#    'url': 'https://api.github.com/repos/AlongWY/ArxivDaily'},
#   'payload': {'push_id': 8712208876,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '27d459bf28aea9b69c895a7a7a84bd8ecded2613',
#    'before': '33d7f58b93940dc5e61119973eea0c4b90a2a53a',
#    'commits': [{'sha': '27d459bf28aea9b69c895a7a7a84bd8ecded2613',
#      'author': {'email': 'AlongWY@users.noreply.github.com',
#       'name': 'AlongWY'},
#      'message': 'deploy: f1f2fa263b71cbb3b534402cb151d7b70d8cc935',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AlongWY/ArxivDaily/commits/27d459bf28aea9b69c895a7a7a84bd8ecded2613'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116334',
#   'type': 'PushEvent',
#   'actor': {'id': 95618128,
#    'login': 'kaduy25',
#    'display_login': 'kaduy25',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kaduy25',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95618128?'},
#   'repo': {'id': 435444902,
#    'name': 'kakuy25/file',
#    'url': 'https://api.github.com/repos/kakuy25/file'},
#   'payload': {'push_id': 8712208887,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ec3e558c48ddd79fe6c2bf2b9b2d74b928ce124b',
#    'before': 'b98dd46c92733b9d4959a417918c2d626d057482',
#    'commits': [{'sha': 'ec3e558c48ddd79fe6c2bf2b9b2d74b928ce124b',
#      'author': {'email': '95618128+kaduy25@users.noreply.github.com',
#       'name': 'kaduy25'},
#      'message': 'add',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kakuy25/file/commits/ec3e558c48ddd79fe6c2bf2b9b2d74b928ce124b'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z',
#   'org': {'id': 95618197,
#    'login': 'kakuy25',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kakuy25',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95618197?'}},
#  {'id': '19506116352',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 37936606,
#    'login': 'github-learning-lab[bot]',
#    'display_login': 'github-learning-lab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-learning-lab[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37936606?'},
#   'repo': {'id': 442463439,
#    'name': 'aapman55/hello-github-actions',
#    'url': 'https://api.github.com/repos/aapman55/hello-github-actions'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/aapman55/hello-github-actions/issues/2',
#     'repository_url': 'https://api.github.com/repos/aapman55/hello-github-actions',
#     'labels_url': 'https://api.github.com/repos/aapman55/hello-github-actions/issues/2/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/aapman55/hello-github-actions/issues/2/comments',
#     'events_url': 'https://api.github.com/repos/aapman55/hello-github-actions/issues/2/events',
#     'html_url': 'https://github.com/aapman55/hello-github-actions/pull/2',
#     'id': 1089878417,
#     'node_id': 'PR_kwDOGl90z84wVexn',
#     'number': 2,
#     'title': 'Create Dockerfile',
#     'user': {'login': 'aapman55',
#      'id': 5768295,
#      'node_id': 'MDQ6VXNlcjU3NjgyOTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5768295?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/aapman55',
#      'html_url': 'https://github.com/aapman55',
#      'followers_url': 'https://api.github.com/users/aapman55/followers',
#      'following_url': 'https://api.github.com/users/aapman55/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/aapman55/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/aapman55/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/aapman55/subscriptions',
#      'organizations_url': 'https://api.github.com/users/aapman55/orgs',
#      'repos_url': 'https://api.github.com/users/aapman55/repos',
#      'events_url': 'https://api.github.com/users/aapman55/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/aapman55/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2021-12-28T12:57:43Z',
#     'updated_at': '2021-12-28T13:03:22Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/aapman55/hello-github-actions/pulls/2',
#      'html_url': 'https://github.com/aapman55/hello-github-actions/pull/2',
#      'diff_url': 'https://github.com/aapman55/hello-github-actions/pull/2.diff',
#      'patch_url': 'https://github.com/aapman55/hello-github-actions/pull/2.patch',
#      'merged_at': None},
#     'body': None,
#     'reactions': {'url': 'https://api.github.com/repos/aapman55/hello-github-actions/issues/2/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/aapman55/hello-github-actions/issues/2/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/aapman55/hello-github-actions/issues/comments/1002095445',
#     'html_url': 'https://github.com/aapman55/hello-github-actions/pull/2#issuecomment-1002095445',
#     'issue_url': 'https://api.github.com/repos/aapman55/hello-github-actions/issues/2',
#     'id': 1002095445,
#     'node_id': 'IC_kwDOGl90z847usNV',
#     'user': {'login': 'github-learning-lab[bot]',
#      'id': 37936606,
#      'node_id': 'MDM6Qm90Mzc5MzY2MDY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/10572?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-learning-lab',
#      'followers_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-12-28T13:03:22Z',
#     'updated_at': '2021-12-28T13:03:22Z',
#     'author_association': 'NONE',
#     'body': 'Nice, you just added an action block to your workflow file! Here are some important details about _why_ each part of the block exists and _what_ each part does.\n\n- `jobs:` is the base component of a workflow run\n- `build:` is the identifier we\'re attaching to this job\n- `name:` is the name of the job, this is displayed on GitHub when the workflow is running\n- `runs-on:` defines the type of machine to run the job on. The machine can be either a GitHub-hosted runner or a self-hosted runner.\n- `steps:` the linear sequence of operations that make up a job\n- `uses: actions/checkout@v1` uses a community action called [`checkout`](https://github.com/actions/checkout) to allow the workflow to access the contents of the repository\n- `uses: ./action-a` provides the relative path to the action we created in the `action-a` directory of the repository\n- `with`: is used to specify the input variables that will be available to your action in the runtime environment. In this case, the input variable is `MY_NAME`, and it is currently initialized to `"Mona"`.\n\n### Your action has been triggered!\n\nYour repository now contains an action (defined in the `/action-a/` folder) and a workflow (defined in the `./github/workflows/main.yml` file).\n\nThis action will run any time a new commit is created or pushed to the remote repository. Since you just created a commit, the workflow should have been triggered. This might take a few minutes since it\'s the first time running in this repository.\n\n### Seeing your Action in action\n\nThe status of your action is shown here in the pull request (look for **All checks have passed** below), or you can click the "Actions" tab in your repository. From there you will see the actions that have run, and you can click on the action\'s "Log" link to view details.\n\n![View an action\'s log](https://user-images.githubusercontent.com/16547949/62388049-4e64e600-b52a-11e9-8bf5-db0c5452360f.png)\n\n## Step 6: Trigger the workflow\n\n### :keyboard: Activity: See your action trigger the workflow\n\nYou\'ve done the work, now sit back and see your action trigger the workflow!\n\n<hr>\n<h3 align="center">I will respond when I detect your action has run and reported a status.</h3>\n\n> _Actions can take a minute or two to run. Sometimes, I also respond too fast for the page to update! If you don\'t see a response from your action, wait a few seconds and refresh the page._\n',
#     'reactions': {'url': 'https://api.github.com/repos/aapman55/hello-github-actions/issues/comments/1002095445/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116330',
#   'type': 'IssuesEvent',
#   'actor': {'id': 5655515,
#    'login': 'emylincon',
#    'display_login': 'emylincon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/emylincon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?'},
#   'repo': {'id': 442260120,
#    'name': 'emylincon/golist',
#    'url': 'https://api.github.com/repos/emylincon/golist'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/emylincon/golist/issues/9',
#     'repository_url': 'https://api.github.com/repos/emylincon/golist',
#     'labels_url': 'https://api.github.com/repos/emylincon/golist/issues/9/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/emylincon/golist/issues/9/comments',
#     'events_url': 'https://api.github.com/repos/emylincon/golist/issues/9/events',
#     'html_url': 'https://github.com/emylincon/golist/issues/9',
#     'id': 1089846571,
#     'node_id': 'I_kwDOGlxamM5A9b0r',
#     'number': 9,
#     'title': '[FEATURE] Add reverse sort functionality',
#     'user': {'login': 'emylincon',
#      'id': 5655515,
#      'node_id': 'MDQ6VXNlcjU2NTU1MTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/emylincon',
#      'html_url': 'https://github.com/emylincon',
#      'followers_url': 'https://api.github.com/users/emylincon/followers',
#      'following_url': 'https://api.github.com/users/emylincon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/emylincon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/emylincon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/emylincon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/emylincon/orgs',
#      'repos_url': 'https://api.github.com/users/emylincon/repos',
#      'events_url': 'https://api.github.com/users/emylincon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/emylincon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 3679205040,
#       'node_id': 'LA_kwDOGlxamM7bTDaw',
#       'url': 'https://api.github.com/repos/emylincon/golist/labels/Feature',
#       'name': 'Feature',
#       'color': '1d76db',
#       'default': False,
#       'description': 'New feature'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'emylincon',
#      'id': 5655515,
#      'node_id': 'MDQ6VXNlcjU2NTU1MTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/emylincon',
#      'html_url': 'https://github.com/emylincon',
#      'followers_url': 'https://api.github.com/users/emylincon/followers',
#      'following_url': 'https://api.github.com/users/emylincon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/emylincon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/emylincon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/emylincon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/emylincon/orgs',
#      'repos_url': 'https://api.github.com/users/emylincon/repos',
#      'events_url': 'https://api.github.com/users/emylincon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/emylincon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'emylincon',
#       'id': 5655515,
#       'node_id': 'MDQ6VXNlcjU2NTU1MTU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5655515?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/emylincon',
#       'html_url': 'https://github.com/emylincon',
#       'followers_url': 'https://api.github.com/users/emylincon/followers',
#       'following_url': 'https://api.github.com/users/emylincon/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/emylincon/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/emylincon/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/emylincon/subscriptions',
#       'organizations_url': 'https://api.github.com/users/emylincon/orgs',
#       'repos_url': 'https://api.github.com/users/emylincon/repos',
#       'events_url': 'https://api.github.com/users/emylincon/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/emylincon/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2021-12-28T12:04:17Z',
#     'updated_at': '2021-12-28T13:03:22Z',
#     'closed_at': '2021-12-28T13:03:22Z',
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': 'Add ability to sort reverse or not',
#     'reactions': {'url': 'https://api.github.com/repos/emylincon/golist/issues/9/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/emylincon/golist/issues/9/timeline',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116329',
#   'type': 'PushEvent',
#   'actor': {'id': 80118008,
#    'login': 'LearAdini',
#    'display_login': 'LearAdini',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LearAdini',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80118008?'},
#   'repo': {'id': 442411352,
#    'name': 'LearAdini/Angular-Json-Pipe',
#    'url': 'https://api.github.com/repos/LearAdini/Angular-Json-Pipe'},
#   'payload': {'push_id': 8712208873,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5ecaaf8d5137982a761049d310eb4a5855f6ef4b',
#    'before': '6fb8bd3887c34392aa6bd5d0dad89461888e05d3',
#    'commits': [{'sha': '5ecaaf8d5137982a761049d310eb4a5855f6ef4b',
#      'author': {'email': '80118008+LearAdini@users.noreply.github.com',
#       'name': 'LearAdini'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LearAdini/Angular-Json-Pipe/commits/5ecaaf8d5137982a761049d310eb4a5855f6ef4b'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116319',
#   'type': 'PushEvent',
#   'actor': {'id': 90617189,
#    'login': 'alex23140',
#    'display_login': 'alex23140',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alex23140',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90617189?'},
#   'repo': {'id': 442236813,
#    'name': 'alex23140/Task_313_Rest_JS_2',
#    'url': 'https://api.github.com/repos/alex23140/Task_313_Rest_JS_2'},
#   'payload': {'push_id': 8712208871,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '56d0af09c59495109de6eae4bdf82b47ef9e09ee',
#    'before': '1f2b2b7e1f9fb0651701fea57c42dabb6e4ad4ec',
#    'commits': [{'sha': '56d0af09c59495109de6eae4bdf82b47ef9e09ee',
#      'author': {'email': 'xteamx23@gmail.com', 'name': 'alex23140'},
#      'message': '1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alex23140/Task_313_Rest_JS_2/commits/56d0af09c59495109de6eae4bdf82b47ef9e09ee'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116297',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 377469820,
#    'name': 'bernardobfg/bernardobfg',
#    'url': 'https://api.github.com/repos/bernardobfg/bernardobfg'},
#   'payload': {'push_id': 8712208869,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '4649582a13115ad27a81abd5b5a7b2d3b6ddb46e',
#    'before': 'dfb6aeb0bb739b5f6e00f4eba27ea2c78a2e65bc',
#    'commits': [{'sha': '4649582a13115ad27a81abd5b5a7b2d3b6ddb46e',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bernardobfg/bernardobfg/commits/4649582a13115ad27a81abd5b5a7b2d3b6ddb46e'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116311',
#   'type': 'CreateEvent',
#   'actor': {'id': 96077910,
#    'login': 'vikas1683',
#    'display_login': 'vikas1683',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vikas1683',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96077910?'},
#   'repo': {'id': 442456469,
#    'name': 'vikas1683/restaurant-app',
#    'url': 'https://api.github.com/repos/vikas1683/restaurant-app'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'This is restaurant app',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116295',
#   'type': 'PushEvent',
#   'actor': {'id': 28897553,
#    'login': 'Stueckgut',
#    'display_login': 'Stueckgut',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Stueckgut',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28897553?'},
#   'repo': {'id': 127952477,
#    'name': 'Stueckgut/live-ticker',
#    'url': 'https://api.github.com/repos/Stueckgut/live-ticker'},
#   'payload': {'push_id': 8712208867,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd65d981f2f4803c8d91e83a32284d2285e5bafba',
#    'before': '358f35b9ebc97b0cb9cb25a545c89fa4581b4778',
#    'commits': [{'sha': 'd65d981f2f4803c8d91e83a32284d2285e5bafba',
#      'author': {'email': 'info@stueckgut-hamburg.de', 'name': 'System'},
#      'message': 'update value',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Stueckgut/live-ticker/commits/d65d981f2f4803c8d91e83a32284d2285e5bafba'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116326',
#   'type': 'CreateEvent',
#   'actor': {'id': 93684939,
#    'login': 'ADSDummyUser',
#    'display_login': 'ADSDummyUser',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ADSDummyUser',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93684939?'},
#   'repo': {'id': 422316826,
#    'name': 'ADSDummyUser/Knowledge_Base',
#    'url': 'https://api.github.com/repos/ADSDummyUser/Knowledge_Base'},
#   'payload': {'ref': 'ssjgo@iscte-iul.pt_0',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116322',
#   'type': 'PushEvent',
#   'actor': {'id': 96767297,
#    'login': '647gdfg',
#    'display_login': '647gdfg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/647gdfg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96767297?'},
#   'repo': {'id': 442458679,
#    'name': '647gdfg/761ad759-44c4-4ced-bd97-45c7d1ac1799',
#    'url': 'https://api.github.com/repos/647gdfg/761ad759-44c4-4ced-bd97-45c7d1ac1799'},
#   'payload': {'push_id': 8712208864,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f27ebce097d4e205b7e851d5ed631f39c6d96141',
#    'before': 'c9d39af980eb6d0340ca1e73aa5bcd614cf120d0',
#    'commits': [{'sha': 'f27ebce097d4e205b7e851d5ed631f39c6d96141',
#      'author': {'email': '96767297+647gdfg@users.noreply.github.com',
#       'name': '647gdfg'},
#      'message': 'upload file ce320d452d703b3bf4cba89da6d6b1ada15c3ebecea51ddef2639ea6a8f116ae06cdf42092009e60070fec58ee9435aevideo_1567_0_1552094.ts',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/647gdfg/761ad759-44c4-4ced-bd97-45c7d1ac1799/commits/f27ebce097d4e205b7e851d5ed631f39c6d96141'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116312',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 24769365,
#    'login': 'juancarlosestradanieto',
#    'display_login': 'juancarlosestradanieto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juancarlosestradanieto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24769365?'},
#   'repo': {'id': 434971581,
#    'name': 'usevilla-fis-2021-g4/frontend',
#    'url': 'https://api.github.com/repos/usevilla-fis-2021-g4/frontend'},
#   'payload': {'action': 'closed',
#    'number': 6,
#    'pull_request': {'url': 'https://api.github.com/repos/usevilla-fis-2021-g4/frontend/pulls/6',
#     'id': 810940282,
#     'node_id': 'PR_kwDOGe0jvc4wVfd6',
#     'html_url': 'https://github.com/usevilla-fis-2021-g4/frontend/pull/6',
#     'diff_url': 'https://github.com/usevilla-fis-2021-g4/frontend/pull/6.diff',
#     'patch_url': 'https://github.com/usevilla-fis-2021-g4/frontend/pull/6.patch',
#     'issue_url': 'https://api.github.com/repos/usevilla-fis-2021-g4/frontend/issues/6',
#     'number': 6,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Added generate password feature',
#     'user': {'login': 'juancarlosestradanieto',
#      'id': 24769365,
#      'node_id': 'MDQ6VXNlcjI0NzY5MzY1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/24769365?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/juancarlosestradanieto',
#      'html_url': 'https://github.com/juancarlosestradanieto',
#      'followers_url': 'https://api.github.com/users/juancarlosestradanieto/followers',
#      'following_url': 'https://api.github.com/users/juancarlosestradanieto/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/juancarlosestradanieto/gists{/gist_id}',
# ...
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/benjaminSchilling33',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16476665?'},
#   'repo': {'id': 305083478,
#    'name': 'houseos/houseos.github.io',
#    'url': 'https://api.github.com/repos/houseos/houseos.github.io'},
#   'payload': {'push_id': 8712208830,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7584aa0655c634293f53d2b22dc5637ab192ea11',
#    'before': '45e88daf19ccd0810eb1095a32ee18c25fc4b9ea',
#    'commits': [{'sha': '7584aa0655c634293f53d2b22dc5637ab192ea11',
#      'author': {'email': 'benjamin.schilling33@gmail.com',
#       'name': 'Benjamin Schilling'},
#      'message': 'fix mkdocs yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/houseos/houseos.github.io/commits/7584aa0655c634293f53d2b22dc5637ab192ea11'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z',
#   'org': {'id': 65420009,
#    'login': 'houseos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/houseos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65420009?'}},
#  {'id': '19506116269',
#   'type': 'ForkEvent',
#   'actor': {'id': 64311249,
#    'login': 'neuro-core',
#    'display_login': 'neuro-core',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/neuro-core',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64311249?'},
#   'repo': {'id': 227658982,
#    'name': 'NVIDIA/VideoProcessingFramework',
#    'url': 'https://api.github.com/repos/NVIDIA/VideoProcessingFramework'},
#   'payload': {'forkee': {'id': 442465493,
#     'node_id': 'R_kgDOGl981Q',
#     'name': 'VideoProcessingFramework',
#     'full_name': 'neuro-core/VideoProcessingFramework',
#     'private': False,
#     'owner': {'login': 'neuro-core',
#      'id': 64311249,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY0MzExMjQ5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/64311249?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/neuro-core',
#      'html_url': 'https://github.com/neuro-core',
#      'followers_url': 'https://api.github.com/users/neuro-core/followers',
#      'following_url': 'https://api.github.com/users/neuro-core/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/neuro-core/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/neuro-core/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/neuro-core/subscriptions',
#      'organizations_url': 'https://api.github.com/users/neuro-core/orgs',
#      'repos_url': 'https://api.github.com/users/neuro-core/repos',
#      'events_url': 'https://api.github.com/users/neuro-core/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/neuro-core/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/neuro-core/VideoProcessingFramework',
#     'description': 'Set of Python bindings to C++ libraries which provides full HW acceleration for video decoding, encoding and GPU-accelerated color space and pixel format conversions',
#     'fork': True,
#     'url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework',
#     'forks_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/forks',
#     'keys_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/teams',
#     'hooks_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/hooks',
#     'issue_events_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/events',
#     'assignees_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/tags',
#     'blobs_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/languages',
#     'stargazers_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/stargazers',
#     'contributors_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/contributors',
#     'subscribers_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/subscribers',
#     'subscription_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/subscription',
#     'commits_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/merges',
#     'archive_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/downloads',
#     'issues_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/neuro-core/VideoProcessingFramework/deployments',
#     'created_at': '2021-12-28T13:03:21Z',
#     'updated_at': '2021-12-28T11:50:00Z',
#     'pushed_at': '2021-12-28T10:21:36Z',
#     'git_url': 'git://github.com/neuro-core/VideoProcessingFramework.git',
#     'ssh_url': 'git@github.com:neuro-core/VideoProcessingFramework.git',
#     'clone_url': 'https://github.com/neuro-core/VideoProcessingFramework.git',
#     'svn_url': 'https://github.com/neuro-core/VideoProcessingFramework',
#     'homepage': None,
#     'size': 1847,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'apache-2.0',
#      'name': 'Apache License 2.0',
#      'spdx_id': 'Apache-2.0',
#      'url': 'https://api.github.com/licenses/apache-2.0',
#      'node_id': 'MDc6TGljZW5zZTI='},
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z',
#   'org': {'id': 1728152,
#    'login': 'NVIDIA',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/NVIDIA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1728152?'}},
#  {'id': '19506116275',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 389712306,
#    'name': 'Felipe305/Felipe305',
#    'url': 'https://api.github.com/repos/Felipe305/Felipe305'},
#   'payload': {'push_id': 8712208842,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '2cbf736f5d3f646b026814e2e1fba515f38be022',
#    'before': 'ff16d69cc02d90675b79aa19eb78b2cad34a6ced',
#    'commits': [{'sha': '2cbf736f5d3f646b026814e2e1fba515f38be022',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Felipe305/Felipe305/commits/2cbf736f5d3f646b026814e2e1fba515f38be022'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116268',
#   'type': 'WatchEvent',
#   'actor': {'id': 3277073,
#    'login': 'engincancan',
#    'display_login': 'engincancan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/engincancan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3277073?'},
#   'repo': {'id': 281804942,
#    'name': 'a1xd/rawaccel',
#    'url': 'https://api.github.com/repos/a1xd/rawaccel'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116284',
#   'type': 'PushEvent',
#   'actor': {'id': 83404206,
#    'login': 'RizzoGR',
#    'display_login': 'RizzoGR',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RizzoGR',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83404206?'},
#   'repo': {'id': 442442190,
#    'name': 'RizzoGR/RizzoGR.github.io',
#    'url': 'https://api.github.com/repos/RizzoGR/RizzoGR.github.io'},
#   'payload': {'push_id': 8712208845,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ceed93b35eae8162254e0eb09a48c5e87b0dee11',
#    'before': '0e936ae4499dee2e100a2a3ab970dbefe842ef5b',
#    'commits': [{'sha': 'ceed93b35eae8162254e0eb09a48c5e87b0dee11',
#      'author': {'email': '83404206+RizzoGR@users.noreply.github.com',
#       'name': 'Gabriele Rizzo'},
#      'message': 'Delete .gitmodules',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RizzoGR/RizzoGR.github.io/commits/ceed93b35eae8162254e0eb09a48c5e87b0dee11'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116264',
#   'type': 'PushEvent',
#   'actor': {'id': 96052245,
#    'login': 'liiiib',
#    'display_login': 'liiiib',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/liiiib',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96052245?'},
#   'repo': {'id': 442427806,
#    'name': 'liiiib/9b1862b4-ad4f-4f14-90b5-0adad69a2126',
#    'url': 'https://api.github.com/repos/liiiib/9b1862b4-ad4f-4f14-90b5-0adad69a2126'},
#   'payload': {'push_id': 8712208848,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e447cc79d98fbc057b2eb51a0de07b97d294a513',
#    'before': 'b6c661e5b79c54079b0ec80bdb6114f364fd87ce',
#    'commits': [{'sha': 'e447cc79d98fbc057b2eb51a0de07b97d294a513',
#      'author': {'email': '96052245+liiiib@users.noreply.github.com',
#       'name': 'liiiib'},
#      'message': 'upload file 3097eb8c7c76bcc650ba332c7bf71832c59890b415d95532abba99005b11701ebfcc54db6f37491f47f313b27bfaad50video_1345_0_1723697.ts',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/liiiib/9b1862b4-ad4f-4f14-90b5-0adad69a2126/commits/e447cc79d98fbc057b2eb51a0de07b97d294a513'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116288',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 397395460,
#    'name': 'Joey-Resende/Joey-Resende',
#    'url': 'https://api.github.com/repos/Joey-Resende/Joey-Resende'},
#   'payload': {'push_id': 8712208850,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '2ea555262f0460e3f7ac4b50c5a2554c092b2235',
#    'before': '1e61a9447049cbf7026d39220c639d5d00dc239e',
#    'commits': [{'sha': '2ea555262f0460e3f7ac4b50c5a2554c092b2235',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Joey-Resende/Joey-Resende/commits/2ea555262f0460e3f7ac4b50c5a2554c092b2235'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116263',
#   'type': 'PushEvent',
#   'actor': {'id': 88271958,
#    'login': 'DmitryK8',
#    'display_login': 'DmitryK8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DmitryK8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88271958?'},
#   'repo': {'id': 441177643,
#    'name': 'DmitryK8/DZ_5.1_card_delivery_order',
#    'url': 'https://api.github.com/repos/DmitryK8/DZ_5.1_card_delivery_order'},
#   'payload': {'push_id': 8712208840,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ef1f5e43e14dfb0f81e99983001b179ca2218303',
#    'before': '3d9c80effe9371e20a0db541f1ba368c481bfa97',
#    'commits': [{'sha': 'ef1f5e43e14dfb0f81e99983001b179ca2218303',
#      'author': {'email': 'd.k.12.1972@gmail.com', 'name': 'Dmitry Kravchenko'},
#      'message': 'устранил замечания преподавателя',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DmitryK8/DZ_5.1_card_delivery_order/commits/ef1f5e43e14dfb0f81e99983001b179ca2218303'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116267',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 272312485,
#    'name': 'Calvin-LL/webpack-image-resize-loader',
#    'url': 'https://api.github.com/repos/Calvin-LL/webpack-image-resize-loader'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/typescript-eslint/parser-5.8.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'},
#  {'id': '19506116255',
#   'type': 'PushEvent',
#   'actor': {'id': 4775096,
#    'login': 'Samith88',
#    'display_login': 'Samith88',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Samith88',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4775096?'},
#   'repo': {'id': 382777703,
#    'name': 'Samith88/OfficerDataManagement',
#    'url': 'https://api.github.com/repos/Samith88/OfficerDataManagement'},
#   'payload': {'push_id': 8712208834,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4cb3c83f9796efb0454120cfcba0a863b667760f',
#    'before': '0c7e5d86d3105033cc6b29c4e2a71deb4ccdc803',
#    'commits': [{'sha': '4cb3c83f9796efb0454120cfcba0a863b667760f',
#      'author': {'email': 'samith.dissanayake@pearson.com',
#       'name': 'Dissanayake'},
#      'message': 'Modified officer table with unicode headers',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Samith88/OfficerDataManagement/commits/4cb3c83f9796efb0454120cfcba0a863b667760f'}]},
#   'public': True,
#   'created_at': '2021-12-28T13:03:22Z'}]

# %% [markdown]
# # 定制请求头

# %%
url = 'https://api.github.com/some/endpoint'
headers = {'user-agent': 'my-app/0.0.1'}

r = requests.get(url, headers=headers)
